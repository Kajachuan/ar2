# %%
import os
import gymnasium
import highway_env
import warnings
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env

env_name = 'highway-v0'
root = f'{env_name}-PPO-D'

warnings.filterwarnings("ignore", category=DeprecationWarning)

# ── Configuración ────────────────────────────────────────────────────────────
config = {
    "observation": {
        "type": "Kinematics",
        "vehicles_count": 15,
        "features": ["presence", "x", "y", "vx", "vy"],
        "features_range": {
            "x": [-100, 100],
            "y": [-100, 100],
            "vx": [-30, 30],
            "vy": [-30, 30],
        },
        "absolute": False,
        "order": "sorted",
        "normalize": True,
    },

    "action": {
        "type": "DiscreteMetaAction",
    },

    "lanes_count": 4,
    "vehicles_count": 50,
    "vehicles_density": 1.2,
    "duration": 60,
    "initial_lane_id": None,

    "simulation_frequency": 15,
    "policy_frequency": 5,

    "collision_reward": -2.0,
    "high_speed_reward": 2.5,
    "lane_change_reward": -0.05,
    "right_lane_reward": 0.0,
    "reward_speed_range": [20, 30],
    "normalize_reward": True,

    "offroad_terminal": True,
    "controlled_vehicles": 1,
    "manual_control": False,
}

log_dir = f"{root}/logs/"
os.makedirs(log_dir, exist_ok=True)

# ── Entornos ─────────────────────────────────────────────────────────────────
env = make_vec_env(env_name, n_envs=8, monitor_dir=log_dir, env_kwargs={"config": config})

# ── Modelo (Carga o Creación) ──────────────────────────────────────────────────
TOTAL_TIMESTEPS = 200_000

print("Creando modelo desde cero...")
model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    n_steps=256,
    batch_size=256,
    gae_lambda=0.95,
    gamma=0.99,
    n_epochs=10,
    learning_rate=3e-4,
    clip_range=0.2,
    ent_coef=0.05,
    policy_kwargs=dict(
        net_arch=[256, 256]
    ),
)

# ── Entrenamiento ─────────────────────────────────────────────────────────────
try:
    print("Entrenando al agente...")
    model.learn(total_timesteps=TOTAL_TIMESTEPS)
except KeyboardInterrupt:
    print("\nEntrenamiento interrumpido por el usuario (Ctrl+C). Guardando estado actual...")

finally:
    print("Guardando modelo...")
    model.save(f"{log_dir}/ppo_discrete_model")
    
    env.close()
    print("Entornos cerrados correctamente.")
# Out:
# <frozen importlib._bootstrap>:488: RuntimeWarning: Your system is avx2 capable but pygame was not built with support for it. The performance of some of your blits could be adversely affected. Consider enabling compile time detection with environment variables like PYGAME_DETECT_AVX2=1 if you are compiling without cross compilation.
# Creando modelo desde cero...
# Using cpu device
# Entrenando al agente...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 33.3     |
# |    ep_rew_mean     | 22.8     |
# | time/              |          |
# |    fps             | 11       |
# |    iterations      | 1        |
# |    time_elapsed    | 177      |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.3        |
# |    ep_rew_mean          | 24.3        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 2           |
# |    time_elapsed         | 373         |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008747872 |
# |    clip_fraction        | 0.0885      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | -0.00355    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.35        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.2        |
# |    ep_rew_mean          | 24.1        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 3           |
# |    time_elapsed         | 555         |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008778658 |
# |    clip_fraction        | 0.0191      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.0381      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00227    |
# |    value_loss           | 25.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 38.5        |
# |    ep_rew_mean          | 25.6        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 4           |
# |    time_elapsed         | 738         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008056615 |
# |    clip_fraction        | 0.029       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.0549      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00431    |
# |    value_loss           | 30.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.7        |
# |    ep_rew_mean          | 24.5        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 5           |
# |    time_elapsed         | 923         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.010526232 |
# |    clip_fraction        | 0.0681      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.0689      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00544    |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36.7        |
# |    ep_rew_mean          | 25.8        |
# | time/                   |             |
# |    fps                  | 11          |
# |    iterations           | 6           |
# |    time_elapsed         | 1111        |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009115293 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | 0.0949      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 41.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 42.9         |
# |    ep_rew_mean          | 28.5         |
# | time/                   |              |
# |    fps                  | 11           |
# |    iterations           | 7            |
# |    time_elapsed         | 1300         |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0059333644 |
# |    clip_fraction        | 0.00605      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.58        |
# |    explained_variance   | 0.15         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.9         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00251     |
# |    value_loss           | 37.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 46.4        |
# |    ep_rew_mean          | 29.2        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 8           |
# |    time_elapsed         | 1490        |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007442802 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.56       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00575    |
# |    value_loss           | 37.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 51.5        |
# |    ep_rew_mean          | 31.1        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 9           |
# |    time_elapsed         | 1679        |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.011786899 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.2        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 33.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 59.6        |
# |    ep_rew_mean          | 34.6        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 10          |
# |    time_elapsed         | 1867        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009396425 |
# |    clip_fraction        | 0.0423      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.48       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00694    |
# |    value_loss           | 35.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.9        |
# |    ep_rew_mean          | 39.8        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 11          |
# |    time_elapsed         | 2055        |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013986805 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.16        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14          |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 31.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 74.2        |
# |    ep_rew_mean          | 40.9        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 12          |
# |    time_elapsed         | 2243        |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013106521 |
# |    clip_fraction        | 0.0401      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.5        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00149    |
# |    value_loss           | 27.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.5        |
# |    ep_rew_mean          | 45.8        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 13          |
# |    time_elapsed         | 2431        |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.009299507 |
# |    clip_fraction        | 0.0596      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00464    |
# |    value_loss           | 33.7        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 94.4         |
# |    ep_rew_mean          | 50.9         |
# | time/                   |              |
# |    fps                  | 10           |
# |    iterations           | 14           |
# |    time_elapsed         | 2621         |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0128804315 |
# |    clip_fraction        | 0.0573       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.42        |
# |    explained_variance   | 0.488        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.5         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00325     |
# |    value_loss           | 24.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | 57.3        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 15          |
# |    time_elapsed         | 2814        |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.002560689 |
# |    clip_fraction        | 0.0142      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.43       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.4        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000929   |
# |    value_loss           | 22.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | 56.8        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 16          |
# |    time_elapsed         | 3013        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.010308821 |
# |    clip_fraction        | 0.0471      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.42       |
# |    explained_variance   | 0.401       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.9        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00394    |
# |    value_loss           | 41.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 106         |
# |    ep_rew_mean          | 58.7        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 17          |
# |    time_elapsed         | 3235        |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013317414 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | 0.432       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.8        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 42.1        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | 57.9        |
# | time/                   |             |
# |    fps                  | 10          |
# |    iterations           | 18          |
# |    time_elapsed         | 3643        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.007479892 |
# |    clip_fraction        | 0.0455      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.1        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0066     |
# |    value_loss           | 45.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 101         |
# |    ep_rew_mean          | 56.5        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 19          |
# |    time_elapsed         | 3892        |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.005271382 |
# |    clip_fraction        | 0.0278      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.511       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00192    |
# |    value_loss           | 30.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 56.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 20          |
# |    time_elapsed         | 4132        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.008701468 |
# |    clip_fraction        | 0.093       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.491       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.53        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00696    |
# |    value_loss           | 26.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 115          |
# |    ep_rew_mean          | 62.2         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 21           |
# |    time_elapsed         | 4377         |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0062222565 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.57         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.03         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.0056      |
# |    value_loss           | 20.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 128          |
# |    ep_rew_mean          | 67           |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 22           |
# |    time_elapsed         | 4644         |
# |    total_timesteps      | 45056        |
# | train/                  |              |
# |    approx_kl            | 0.0072738295 |
# |    clip_fraction        | 0.0662       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.682        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.63         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 13.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 136         |
# |    ep_rew_mean          | 70          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 23          |
# |    time_elapsed         | 4902        |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.010816401 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.636       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.15        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00363    |
# |    value_loss           | 15.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 151         |
# |    ep_rew_mean          | 76.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 24          |
# |    time_elapsed         | 5179        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008600466 |
# |    clip_fraction        | 0.0415      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00359    |
# |    value_loss           | 30.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 79.1        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 25          |
# |    time_elapsed         | 5435        |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009591103 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.598       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.23        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00478    |
# |    value_loss           | 13.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 173         |
# |    ep_rew_mean          | 85.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 26          |
# |    time_elapsed         | 5668        |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009658363 |
# |    clip_fraction        | 0.068       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.94        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -3.42e-05   |
# |    value_loss           | 25.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 174         |
# |    ep_rew_mean          | 84.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 27          |
# |    time_elapsed         | 5903        |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003561655 |
# |    clip_fraction        | 0.0358      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.393       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.06        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.000818   |
# |    value_loss           | 16.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 177          |
# |    ep_rew_mean          | 85.7         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 28           |
# |    time_elapsed         | 6203         |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0012767534 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.539        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.000339    |
# |    value_loss           | 34           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 180         |
# |    ep_rew_mean          | 86.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 29          |
# |    time_elapsed         | 6452        |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.007894289 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.26        |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00661    |
# |    value_loss           | 15          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 176         |
# |    ep_rew_mean          | 84.3        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 30          |
# |    time_elapsed         | 6706        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.012909178 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.29        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0029     |
# |    value_loss           | 12.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 182          |
# |    ep_rew_mean          | 86.9         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 31           |
# |    time_elapsed         | 6961         |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0071274573 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10           |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0034      |
# |    value_loss           | 20.8         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 192        |
# |    ep_rew_mean          | 91.1       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 32         |
# |    time_elapsed         | 7210       |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01034105 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.2       |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.64       |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0107    |
# |    value_loss           | 6.58       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 192          |
# |    ep_rew_mean          | 91.2         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 33           |
# |    time_elapsed         | 7462         |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0062049683 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.17        |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.7         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00355     |
# |    value_loss           | 29.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 196          |
# |    ep_rew_mean          | 92.8         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 34           |
# |    time_elapsed         | 7708         |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0038129345 |
# |    clip_fraction        | 0.068        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.58         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.2          |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00413     |
# |    value_loss           | 17.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 92.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 35          |
# |    time_elapsed         | 7942        |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.011655839 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.22        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00115    |
# |    value_loss           | 8.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 93.9        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 36          |
# |    time_elapsed         | 8245        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.005410701 |
# |    clip_fraction        | 0.0803      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.68        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 10.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 208        |
# |    ep_rew_mean          | 98         |
# | time/                   |            |
# |    fps                  | 8          |
# |    iterations           | 37         |
# |    time_elapsed         | 8534       |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00525387 |
# |    clip_fraction        | 0.0851     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.625      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.98       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.00338   |
# |    value_loss           | 16.2       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 224         |
# |    ep_rew_mean          | 106         |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 38          |
# |    time_elapsed         | 8816        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.006804534 |
# |    clip_fraction        | 0.0331      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.02        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00321    |
# |    value_loss           | 8.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 39          |
# |    time_elapsed         | 9052        |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.013024349 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.62        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 4.7         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 40          |
# |    time_elapsed         | 9286        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.011312726 |
# |    clip_fraction        | 0.0504      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12          |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.00553    |
# |    value_loss           | 19.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 218         |
# |    ep_rew_mean          | 103         |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 41          |
# |    time_elapsed         | 9527        |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.008835337 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.51        |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.00249    |
# |    value_loss           | 16.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 99.6        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 42          |
# |    time_elapsed         | 9759        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.013890913 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.605       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.7        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00729    |
# |    value_loss           | 25          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 221          |
# |    ep_rew_mean          | 104          |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 43           |
# |    time_elapsed         | 10004        |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0076034535 |
# |    clip_fraction        | 0.051        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.8         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00217     |
# |    value_loss           | 21.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 221         |
# |    ep_rew_mean          | 105         |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 44          |
# |    time_elapsed         | 10258       |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.010585615 |
# |    clip_fraction        | 0.0164      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.802       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.12        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00182    |
# |    value_loss           | 9.83        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 102         |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 45          |
# |    time_elapsed         | 10509       |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.004017946 |
# |    clip_fraction        | 0.0124      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.36        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.000376   |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 207         |
# |    ep_rew_mean          | 97.8        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 46          |
# |    time_elapsed         | 10748       |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.015517725 |
# |    clip_fraction        | 0.0987      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.639       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.1        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.000881   |
# |    value_loss           | 23.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 208          |
# |    ep_rew_mean          | 98           |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 47           |
# |    time_elapsed         | 10988        |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0048253927 |
# |    clip_fraction        | 0.0559       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.732        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.03         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00219     |
# |    value_loss           | 10.4         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 200         |
# |    ep_rew_mean          | 94.2        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 48          |
# |    time_elapsed         | 11247       |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.014630112 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.554       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.27        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00567    |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | 93.4         |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 49           |
# |    time_elapsed         | 11488        |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0039392565 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.44         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.5         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00549     |
# |    value_loss           | 29           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 201          |
# |    ep_rew_mean          | 94.4         |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 50           |
# |    time_elapsed         | 11732        |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0020169667 |
# |    clip_fraction        | 0.0376       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.62         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00354     |
# |    value_loss           | 28.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 204         |
# |    ep_rew_mean          | 95.8        |
# | time/                   |             |
# |    fps                  | 8           |
# |    iterations           | 51          |
# |    time_elapsed         | 11944       |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009527883 |
# |    clip_fraction        | 0.0442      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.24       |
# |    explained_variance   | 0.532       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.28        |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00151    |
# |    value_loss           | 21.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 202          |
# |    ep_rew_mean          | 95           |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 52           |
# |    time_elapsed         | 12123        |
# |    total_timesteps      | 106496       |
# | train/                  |              |
# |    approx_kl            | 0.0071216715 |
# |    clip_fraction        | 0.0104       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.417        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.4         |
# |    n_updates            | 510          |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 31.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 203          |
# |    ep_rew_mean          | 95.3         |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 53           |
# |    time_elapsed         | 12310        |
# |    total_timesteps      | 108544       |
# | train/                  |              |
# |    approx_kl            | 0.0017044015 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.604        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.16         |
# |    n_updates            | 520          |
# |    policy_gradient_loss | -0.00377     |
# |    value_loss           | 20           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 207          |
# |    ep_rew_mean          | 97.2         |
# | time/                   |              |
# |    fps                  | 8            |
# |    iterations           | 54           |
# |    time_elapsed         | 12491        |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0067792814 |
# |    clip_fraction        | 0.00986      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.25        |
# |    explained_variance   | 0.749        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.16         |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.00097     |
# |    value_loss           | 14.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 209         |
# |    ep_rew_mean          | 98.5        |
# | time/                   |             |
# ...
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 99.4        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 81          |
# |    time_elapsed         | 17456       |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.007842194 |
# |    clip_fraction        | 0.0451      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00346    |
# |    value_loss           | 36.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# |    ep_rew_mean          | 99.4         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 82           |
# |    time_elapsed         | 17637        |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0022029849 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.3         |
# |    explained_variance   | 0.608        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.62         |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.00327     |
# |    value_loss           | 23.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 95          |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 83          |
# |    time_elapsed         | 17819       |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.010416293 |
# |    clip_fraction        | 0.0356      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.709       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00508    |
# |    value_loss           | 23.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 93.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 84          |
# |    time_elapsed         | 18002       |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.014703041 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.583       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.02        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00416    |
# |    value_loss           | 21.1        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 187        |
# |    ep_rew_mean          | 90.9       |
# | time/                   |            |
# |    fps                  | 9          |
# |    iterations           | 85         |
# |    time_elapsed         | 18184      |
# |    total_timesteps      | 174080     |
# | train/                  |            |
# |    approx_kl            | 0.01067609 |
# |    clip_fraction        | 0.0859     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.32      |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.02       |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.00793   |
# |    value_loss           | 22         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 189          |
# |    ep_rew_mean          | 92.3         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 86           |
# |    time_elapsed         | 18367        |
# |    total_timesteps      | 176128       |
# | train/                  |              |
# |    approx_kl            | 0.0054809456 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | 0.552        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 850          |
# |    policy_gradient_loss | -0.0029      |
# |    value_loss           | 28.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 175          |
# |    ep_rew_mean          | 86.1         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 87           |
# |    time_elapsed         | 18549        |
# |    total_timesteps      | 178176       |
# | train/                  |              |
# |    approx_kl            | 0.0025024042 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.85         |
# |    n_updates            | 860          |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 26.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 172         |
# |    ep_rew_mean          | 85.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 88          |
# |    time_elapsed         | 18731       |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008088898 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.628       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.3        |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.00712    |
# |    value_loss           | 29.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 179         |
# |    ep_rew_mean          | 88.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 89          |
# |    time_elapsed         | 18913       |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.006783586 |
# |    clip_fraction        | 0.0638      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.618       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.4        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00664    |
# |    value_loss           | 28.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 184          |
# |    ep_rew_mean          | 90.5         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 90           |
# |    time_elapsed         | 19095        |
# |    total_timesteps      | 184320       |
# | train/                  |              |
# |    approx_kl            | 0.0064757755 |
# |    clip_fraction        | 0.0498       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.27        |
# |    explained_variance   | 0.623        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.4         |
# |    n_updates            | 890          |
# |    policy_gradient_loss | -0.00594     |
# |    value_loss           | 22.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | 93.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 91          |
# |    time_elapsed         | 19278       |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.009715969 |
# |    clip_fraction        | 0.031       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.517       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.2        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.00463    |
# |    value_loss           | 23.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 95.2        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 92          |
# |    time_elapsed         | 19461       |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.009139824 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.761       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.79        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.000178   |
# |    value_loss           | 14.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 195         |
# |    ep_rew_mean          | 95.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 93          |
# |    time_elapsed         | 19644       |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.015966054 |
# |    clip_fraction        | 0.0702      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.2         |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00345    |
# |    value_loss           | 8.27        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 191         |
# |    ep_rew_mean          | 93.6        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 94          |
# |    time_elapsed         | 19828       |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.006324431 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.666       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.65        |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.00266    |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | 94.7        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 95          |
# |    time_elapsed         | 20011       |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.006645928 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.23       |
# |    explained_variance   | 0.549       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.1        |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.00587    |
# |    value_loss           | 27          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 199          |
# |    ep_rew_mean          | 96.8         |
# | time/                   |              |
# |    fps                  | 9            |
# |    iterations           | 96           |
# |    time_elapsed         | 20195        |
# |    total_timesteps      | 196608       |
# | train/                  |              |
# |    approx_kl            | 0.0068304697 |
# |    clip_fraction        | 0.0963       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.757        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.03         |
# |    n_updates            | 950          |
# |    policy_gradient_loss | -0.0105      |
# |    value_loss           | 15.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 207         |
# |    ep_rew_mean          | 99.9        |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 97          |
# |    time_elapsed         | 20378       |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.018501211 |
# |    clip_fraction        | 0.121       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.81        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00306    |
# |    value_loss           | 8.19        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | 101         |
# | time/                   |             |
# |    fps                  | 9           |
# |    iterations           | 98          |
# |    time_elapsed         | 20560       |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.006950562 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.634       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.9        |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0053     |
# |    value_loss           | 18.2        |
# -----------------------------------------
# Guardando modelo...
# Entornos cerrados correctamente.
